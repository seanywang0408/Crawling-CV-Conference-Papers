# %%
from selenium import webdriver  
import time  
import urllib  
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from slugify import slugify

import random

# %%
driver = webdriver.Chrome('C:\\Users\\xiaoyang\\Downloads\\chromedriver.exe')  

# base_url = "https://openreview.net/group?id=ICLR.cc/2021/Conference"
base_url = "https://openreview.net/group?id=ICLR.cc/2021/Conference#poster-presentations"
# base_url = "https://openreview.net/group?id=ICLR.cc/2021/Conference#spotlight-presentations"

driver.get(base_url)
root = r'.\conferences\ICLR-2021-ALL\Poster'.replace('\\','/')
print(root)
# Out:
# ./conferences/ICLR-2021-ALL/Poster

# %%
elementllist =  driver.find_elements_by_tag_name('h4')

# %%
pdfurllist =  []
pdfnamelist = []
for i, element in enumerate(elementllist): 
    if i == 0:
        continue
    pdfnamelist.append(elementllist[i].text)
    pdfurllist.append(elementllist[i].find_elements_by_xpath('a')[1].get_attribute('href'))

# %%
print(elementllist[0].text)
print(elementllist[1].text)
print(elementllist[-1].text)
print('num of papers: ',len(elementllist)-1)
# Out:
# Vienna, Austria May 04 2021 https://iclr.cc/ iclr2021programchairs@googlegroups.com
# Revisiting Dynamic Convolution via Matrix Decomposition
# EVALUATION OF NEURAL ARCHITECTURES TRAINED WITH SQUARE LOSS VS CROSS-ENTROPY IN CLASSIFICATION TASKS
# num of papers:  693

# %%
pdfurllist
# Out:
# Ek',
#  'https://openreview.net/pdf?id=8HhkbjrWLdE',
#  'https://openreview.net/pdf?id=5NA1PinlGFu',
#  'https://openreview.net/pdf?id=kmqjgSNXby',
#  'https://openreview.net/pdf?id=6YEQUn0QICG',
#  'https://openreview.net/pdf?id=fmOOI2a3tQP',
#  'https://openreview.net/pdf?id=Ti87Pv5Oc8',
#  'https://openreview.net/pdf?id=8xeBUgD8u9',
#  'https://openreview.net/pdf?id=ZK6vTvb84s',
#  'https://openreview.net/pdf?id=h0de3QWtGG',
#  'https://openreview.net/pdf?id=NomEDgIEBwE',
#  'https://openreview.net/pdf?id=OPyWRrcjVQw',
#  'https://openreview.net/pdf?id=gl3D-xY7wLq',
#  'https://openreview.net/pdf?id=HOFxeCutxZR',
#  'https://openreview.net/pdf?id=dFwBosAcJkN',
#  'https://openreview.net/pdf?id=0cmMMy8J5q',
#  'https://openreview.net/pdf?id=p8agn6bmTbr',
#  'https://openreview.net/pdf?id=MjvduJCsE4',
#  'https://openreview.net/pdf?id=V8jrrnwGbuc',
#  'https://openreview.net/pdf?id=YUGG2tFuPM',
#  'https://openreview.net/pdf?id=V1ZHVxJ6dSS',
#  'https://openreview.net/pdf?id=PObuuGVrGaZ',
#  'https://openreview.net/pdf?id=Db4yerZTYkz',
#  'https://openreview.net/pdf?id=sjuuTm4vj0',
#  'https://openreview.net/pdf?id=RqCC_00Bg7V',
#  'https://openreview.net/pdf?id=9YlaeLfuhJF',
#  'https://openreview.net/pdf?id=dKg5D1Z1Lm',
#  'https://openreview.net/pdf?id=Fmg_fQYUejf',
#  'https://openreview.net/pdf?id=BVSM0x3EDK6',
#  'https://openreview.net/pdf?id=l0mSUROpwY',
#  'https://openreview.net/pdf?id=XAS3uKeFWj',
#  'https://openreview.net/pdf?id=Iz3zU3M316D',
#  'https://openreview.net/pdf?id=gV3wdEOGy_V',
#  'https://openreview.net/pdf?id=9GBZBPn0Jx',
#  'https://openreview.net/pdf?id=p5uylG94S68',
#  'https://openreview.net/pdf?id=y06VOYLcQXa',
#  'https://openreview.net/pdf?id=zx_uX-BO7CH',
#  'https://openreview.net/pdf?id=X76iqnUbBjz',
#  'https://openreview.net/pdf?id=krz7T0xU9Z_',
#  'https://openreview.net/pdf?id=Rd138pWXMvG',
#  'https://openreview.net/pdf?id=ipUPfYxWZvM',
#  'https://openreview.net/pdf?id=BXewfAYMmJw',
#  'https://openreview.net/pdf?id=de11dbHzAMF',
#  'https://openreview.net/pdf?id=IMPnRXEWpvr',
#  'https://openreview.net/pdf?id=SZ3wtsXfzQR',
#  'https://openreview.net/pdf?id=QubpWYfdNry',
#  'https://openreview.net/pdf?id=8qDwejCuCN',
#  'https://openreview.net/pdf?id=5lhWG3Hj2By',
#  'https://openreview.net/pdf?id=OMizHuea_HB',
#  'https://openreview.net/pdf?id=6UdQLhqJyFD',
#  'https://openreview.net/pdf?id=vXj_ucZQ4hA',
#  'https://openreview.net/pdf?id=OHgnfSrn2jv',
#  'https://openreview.net/pdf?id=17VnwXYZyhH',
#  'https://openreview.net/pdf?id=o81ZyBCojoA',
#  'https://openreview.net/pdf?id=LhY8QdUGSuw',
#  'https://openreview.net/pdf?id=OOsR8BzCnl5',
#  'https://openreview.net/pdf?id=T6AxtOaWydQ',
#  'https://openreview.net/pdf?id=KTlJT1nof6d',
#  'https://openreview.net/pdf?id=rABUmU3ulQh',
#  'https://openreview.net/pdf?id=jMPcEkJpdD',
#  'https://openreview.net/pdf?id=VVdmjgu7pKM',
#  'https://openreview.net/pdf?id=bjkX6Kzb5H',
#  'https://openreview.net/pdf?id=piLPYqxtWuA',
#  'https://openreview.net/pdf?id=Uu1Nw-eeTxJ',
#  'https://openreview.net/pdf?id=jxdXSW9Doc',
#  'https://openreview.net/pdf?id=AICNpd8ke-m',
#  'https://openreview.net/pdf?id=27acGyyI1BY',
#  'https://openreview.net/pdf?id=q-cnWaaoUTH',
#  'https://openreview.net/pdf?id=tIjRAiFmU3y',
#  'https://openreview.net/pdf?id=1Jv6b0Zq3qi',
#  'https://openreview.net/pdf?id=oxnp2q-PGL4',
#  'https://openreview.net/pdf?id=C0qJUx5dxFb',
#  'https://openreview.net/pdf?id=K5j7D81ABvt',
#  'https://openreview.net/pdf?id=0OlrLvrsHwQ',
#  'https://openreview.net/pdf?id=tnSo6VRLmT',
#  'https://openreview.net/pdf?id=1AoMhc_9jER',
#  'https://openreview.net/pdf?id=HxzSxSxLOJZ',
#  'https://openreview.net/pdf?id=Ov_sMNau-PF',
#  'https://openreview.net/pdf?id=tYxG_OMs9WE',
#  'https://openreview.net/pdf?id=4TSiOTkKe5P',
#  'https://openreview.net/pdf?id=n6jl7fLxrP',
#  'https://openreview.net/pdf?id=ATp1nW2FuZL',
#  'https://openreview.net/pdf?id=N3zUDGN5lO',
#  'https://openreview.net/pdf?id=dgtpE6gKjHn',
#  'https://openreview.net/pdf?id=blfSjHeFM_e',
#  'https://openreview.net/pdf?id=sTeoJiB4uR',
#  'https://openreview.net/pdf?id=jznizqvr15J',
#  'https://openreview.net/pdf?id=3SV-ZePhnZM',
#  'https://openreview.net/pdf?id=F8whUO8HNbP',
#  'https://openreview.net/pdf?id=tHgJoMfy6nI',
#  'https://openreview.net/pdf?id=zElset1Klrp',
#  'https://openreview.net/pdf?id=MxaY4FzOTa',
#  'https://openreview.net/pdf?id=kBVJ2NtiY-',
#  'https://openreview.net/pdf?id=9GsFOUyUPi',
#  'https://openreview.net/pdf?id=A2gNouoXE7',
#  'https://openreview.net/pdf?id=Gu5WqN9J3Fn',
#  'https://openreview.net/pdf?id=dNy_RKzJacY',
#  'https://openreview.net/pdf?id=QoWatN-b8T',
#  'https://openreview.net/pdf?id=d7KBjmI3GmQ',
#  'https://openreview.net/pdf?id=2AL06y9cDE-',
#  'https://openreview.net/pdf?id=z9k8BWL-_2u',
#  'https://openreview.net/pdf?id=hiq1rHO8pNT',
#  'https://openreview.net/pdf?id=6t_dLShIUyZ',
#  'https://openreview.net/pdf?id=AhElGnhU2BV',
#  'https://openreview.net/pdf?id=g21u6nlbPzn',
#  'https://openreview.net/pdf?id=XLfdzwNKzch',
#  'https://openreview.net/pdf?id=0IOX0YcCdTn',
#  'https://openreview.net/pdf?id=vcopnwZ7bC',
#  'https://openreview.net/pdf?id=ijJZbomCJIm',
#  'https://openreview.net/pdf?id=BM---bH_RSh',
#  'https://openreview.net/pdf?id=OqtLIabPTit',
#  'https://openreview.net/pdf?id=eQe8DEWNN2W',
#  'https://openreview.net/pdf?id=DiQD7FWL233',
#  'https://openreview.net/pdf?id=09-528y2Fgf',
#  'https://openreview.net/pdf?id=jP1vTH3inC',
#  'https://openreview.net/pdf?id=qYZD-AO1Vn',
#  'https://openreview.net/pdf?id=-M0QkvBGTTq',
#  'https://openreview.net/pdf?id=CGQ6ENUMX6',
#  'https://openreview.net/pdf?id=TuK6agbdt27',
#  'https://openreview.net/pdf?id=ebS5NUfoMKL',
#  'https://openreview.net/pdf?id=NSBrFgJAHg',
#  'https://openreview.net/pdf?id=Cb54AMqHQFP',
#  'https://openreview.net/pdf?id=MJAqnaC2vO1',
#  'https://openreview.net/pdf?id=4T489T4yav',
#  'https://openreview.net/pdf?id=bhCDO_cEGCz',
#  'https://openreview.net/pdf?id=sy4Kg_ZQmS7',
#  'https://openreview.net/pdf?id=_i3ASPp12WS',
#  'https://openreview.net/pdf?id=bM4Iqfg8M2k',
#  'https://openreview.net/pdf?id=lQdXeXDoWtI',
#  'https://openreview.net/pdf?id=lmTWnm3coJJ',
#  'https://openreview.net/pdf?id=hWr3e3r-oH5',
#  'https://openreview.net/pdf?id=VD_ozqvBy4W',
#  'https://openreview.net/pdf?id=rgFNuJHHXv',
#  'https://openreview.net/pdf?id=YmA86Zo-P_t',
#  'https://openreview.net/pdf?id=ECuvULjFQia',
#  'https://openreview.net/pdf?id=90JprVrJBO',
#  'https://openreview.net/pdf?id=-IXhmY16R3M',
#  'https://openreview.net/pdf?id=6NFBvWlRXaG',
#  'https://openreview.net/pdf?id=UoaQUQREMOs',
#  'https://openreview.net/pdf?id=eU776ZYxEpz',
#  'https://openreview.net/pdf?id=jN5y-zb5Q7m',
#  'https://openreview.net/pdf?id=fylclEqgvgd',
#  'https://openreview.net/pdf?id=7I12hXRi8F',
#  'https://openreview.net/pdf?id=w2Z2OwVNeK',
#  'https://openreview.net/pdf?id=PrzjugOsDeE',
#  'https://openreview.net/pdf?id=CHLhSw9pSw8',
#  'https://openreview.net/pdf?id=bgQek2O63w',
#  'https://openreview.net/pdf?id=Mu2ZxFctAI',
#  'https://openreview.net/pdf?id=jXe91kq3jAq',
#  'https://openreview.net/pdf?id=aUX5Plaq7Oy',
#  'https://openreview.net/pdf?id=IX3Nnir2omJ',
#  'https://openreview.net/pdf?id=qZzy5urZw9',
#  'https://openreview.net/pdf?id=LXMSvPmsm0g',
#  'https://openreview.net/pdf?id=jEYKjPE1xYN',
#  'https://openreview.net/pdf?id=-TwO99rbVRu',
#  'https://openreview.net/pdf?id=CU0APx9LMaL',
#  'https://openreview.net/pdf?id=uQfOy7LrlTR',
#  'https://openreview.net/pdf?id=AWOSz_mMAPx',
#  'https://openreview.net/pdf?id=UvBPbpvHRj-',
#  'https://openreview.net/pdf?id=EKV158tSfwv',
#  'https://openreview.net/pdf?id=193sEnKY1ij',
#  'https://openreview.net/pdf?id=TaYhv-q1Xit',
#  'https://openreview.net/pdf?id=IFqrg1p5Bc',
#  'https://openreview.net/pdf?id=TGFO0DbD_pk',
#  'https://openreview.net/pdf?id=1Fqg133qRaI',
#  'https://openreview.net/pdf?id=Pzj6fzU6wkj',
#  'https://openreview.net/pdf?id=U_mat0b9iv',
#  'https://openreview.net/pdf?id=H0syOoy3Ash',
#  'https://openreview.net/pdf?id=VbLH04pRA3',
#  'https://openreview.net/pdf?id=TiXl51SCNw8',
#  'https://openreview.net/pdf?id=SlrqM9_lyju',
#  'https://openreview.net/pdf?id=YWtLZvLmud7',
#  'https://openreview.net/pdf?id=qzBUIzq5XR2',
#  'https://openreview.net/pdf?id=8wqCDnBmnrT',
#  'https://openreview.net/pdf?id=N0M_4BkQ05i',
#  'https://openreview.net/pdf?id=OQ08SN70M1V',
#  'https://openreview.net/pdf?id=OGg9XnKxFAH',
#  'https://openreview.net/pdf?id=--gvHfE3Xf5',
#  'https://openreview.net/pdf?id=9QLRCVysdlO',
#  'https://openreview.net/pdf?id=kWSeGEeHvF8',
#  'https://openreview.net/pdf?id=V6BjBgku7Ro',
#  'https://openreview.net/pdf?id=rsogjAnYs4z',
#  'https://openreview.net/pdf?id=Iw4ZGwenbXf',
#  'https://openreview.net/pdf?id=8e6BrwU6AjQ',
#  'https://openreview.net/pdf?id=pmj131uIL9H',
#  'https://openreview.net/pdf?id=tiqI7w64JG2',
#  'https://openreview.net/pdf?id=Pz_dcqfcKW8',
#  'https://openreview.net/pdf?id=EQfpYwF3-b',
#  'https://openreview.net/pdf?id=QFYnKlBJYR',
#  'https://openreview.net/pdf?id=xYGNO86OWDH',
#  'https://openreview.net/pdf?id=CF-ZIuSMXRz',
#  'https://openreview.net/pdf?id=3hGNqpI4WS',
#  'https://openreview.net/pdf?id=c_E8kFWfhp0',
#  'https://openreview.net/pdf?id=4dXmpCDGNp7',
#  'https://openreview.net/pdf?id=tGZu6DlbreV',
#  'https://openreview.net/pdf?id=xfmSoxdxFCG',
#  'https://openreview.net/pdf?id=snOgiCYZgJ7',
#  'https://openreview.net/pdf?id=eEn8KTtJOx',
#  'https://openreview.net/pdf?id=hJmtwocEqzc',
#  'https://openreview.net/pdf?id=Hf3qXoiNkR',
#  'https://openreview.net/pdf?id=KmykpuSrjcq',
#  'https://openreview.net/pdf?id=Z4R1vxLbRLO',
#  'https://openreview.net/pdf?id=IDFQI9OY6K',
#  'https://openreview.net/pdf?id=8xLkv08d70T',
#  'https://openreview.net/pdf?id=9ITXiTrAoT',
#  'https://openreview.net/pdf?id=KpfasTaLUpq',
#  'https://openreview.net/pdf?id=5NsEIflpbSv',
#  'https://openreview.net/pdf?id=mNtmhaDkAr',
#  'https://openreview.net/pdf?id=jHefDGsorp5',
#  'https://openreview.net/pdf?id=Vd7lCMvtLqg',
#  'https://openreview.net/pdf?id=O3bqkf_Puys',
#  'https://openreview.net/pdf?id=e8W-hsu_q5',
#  'https://openreview.net/pdf?id=S724o4_WB3',
#  'https://openreview.net/pdf?id=hPWj1qduVw8',
#  'https://openreview.net/pdf?id=aCgLmfhIy_f',
#  'https://openreview.net/pdf?id=H6ATjJ0TKdf',
#  'https://openreview.net/pdf?id=Zbc-ue9p_rE',
#  'https://openreview.net/pdf?id=HHiiQKWsOcV',
#  'https://openreview.net/pdf?id=-N7PBXqOUJZ',
#  'https://openreview.net/pdf?id=yqPnIRhHtZv',
#  'https://openreview.net/pdf?id=o3iritJHLfO',
#  'https://openreview.net/pdf?id=TBIzh9b5eaz',
#  'https://openreview.net/pdf?id=JkfYjnOEo6M',
#  'https://openreview.net/pdf?id=vYVI1CHPaQg',
#  'https://openreview.net/pdf?id=Q1jmmQz72M2',
#  'https://openreview.net/pdf?id=wQRlSUZ5V7B',
#  'https://openreview.net/pdf?id=dlEJsyHGeaL',
#  'https://openreview.net/pdf?id=hpH98mK5Puk',
#  'https://openreview.net/pdf?id=9FWas6YbmB3',
#  'https://openreview.net/pdf?id=1rxHOBjeDUW',
#  'https://openreview.net/pdf?id=7_G8JySGecm',
#  'https://openreview.net/pdf?id=Eql5b1_hTE4',
#  'https://openreview.net/pdf?id=45NZvF1UHam',
#  'https://openreview.net/pdf?id=9G5MIc-goqB',
#  'https://openreview.net/pdf?id=n1HD8M6WGn',
#  'https://openreview.net/pdf?id=I4c4K9vBNny',
#  'https://openreview.net/pdf?id=Yz-XtK5RBxB',
#  'https://openreview.net/pdf?id=fAbkE6ant2',
#  'https://openreview.net/pdf?id=B5VvQrI49Pa',
#  'https://openreview.net/pdf?id=0O_cQfw6uEh',
#  'https://openreview.net/pdf?id=gJYlaqL8i8',
#  'https://openreview.net/pdf?id=hx1IXFHAw7R',
#  'https://openreview.net/pdf?id=r28GdiQF7vM',
#  'https://openreview.net/pdf?id=rkQuFUmUOg3',
#  'https://openreview.net/pdf?id=vhKe9UFbrJo',
#  'https://openreview.net/pdf?id=Ogga20D2HO-',
#  'https://openreview.net/pdf?id=_IM-AfFhna9',
#  'https://openreview.net/pdf?id=ZTFeSBIX9C',
#  'https://openreview.net/pdf?id=ufZN2-aehFa',
#  'https://openreview.net/pdf?id=P0p33rgyoE',
#  'https://openreview.net/pdf?id=3q5IqUrkcF',
#  'https://openreview.net/pdf?id=_TM6rT7tXke',
#  'https://openreview.net/pdf?id=4qR3coiNaIv',
#  'https://openreview.net/pdf?id=QO9-y8also-',
#  'https://openreview.net/pdf?id=kE3vd639uRW',
#  'https://openreview.net/pdf?id=eLfqMl3z3lq',
#  'https://openreview.net/pdf?id=Qun8fv4qSby',
#  'https://openreview.net/pdf?id=rq_Qr0c1Hyo',
#  'https://openreview.net/pdf?id=-qh0M9XWxnv',
#  'https://openreview.net/pdf?id=Ig-VyQc-MLK',
#  'https://openreview.net/pdf?id=2CjEVW-RGOJ',
#  'https://openreview.net/pdf?id=MDsQkFP1Aw',
#  'https://openreview.net/pdf?id=Qr0aRliE_Hb',
#  'https://openreview.net/pdf?id=bJxgv5C3sYc',
#  'https://openreview.net/pdf?id=Drynvt7gg4L',
#  'https://openreview.net/pdf?id=TNkPBBYFkXg',
#  'https://openreview.net/pdf?id=WAISmwsqDsb',
#  'https://openreview.net/pdf?id=N33d7wjgzde',
#  'https://openreview.net/pdf?id=8X2eaSZxTP',
#  'https://openreview.net/pdf?id=KtH8W3S_RE',
#  'https://openreview.net/pdf?id=W3Wf_wKmqm9',
#  'https://openreview.net/pdf?id=vsU0efpivw',
#  'https://openreview.net/pdf?id=qbH974jKUVy',
#  'https://openreview.net/pdf?id=K9bw7vqp_s',
#  'https://openreview.net/pdf?id=XOjv2HxIF6i',
#  'https://openreview.net/pdf?id=7FNqrcPtieT',
#  'https://openreview.net/pdf?id=Ldau9eHU-qO',
#  'https://openreview.net/pdf?id=q_S44KLQ_Aa',
#  'https://openreview.net/pdf?id=NcFEZOi-rLa',
#  'https://openreview.net/pdf?id=te7PVH1sPxJ',
#  'https://openreview.net/pdf?id=AAes_3W-2z',
#  'https://openreview.net/pdf?id=60j5LygnmD',
#  'https://openreview.net/pdf?id=mCtadqIxOJ',
#  'https://openreview.net/pdf?id=w2mYg3d0eot',
#  'https://openreview.net/pdf?id=l35SB-_raSQ',
#  'https://openreview.net/pdf?id=IrM64DGB21',
#  'https://openreview.net/pdf?id=J8_GttYLFgr',
#  'https://openreview.net/pdf?id=chPj_I5KMHG',
#  'https://openreview.net/pdf?id=a3wKPZpGtCF',
#  'https://openreview.net/pdf?id=FX0vR39SJ5q',
#  'https://openreview.net/pdf?id=RSU17UoKfJF',
#  'https://openreview.net/pdf?id=C70cp4Cn32',
#  'https://openreview.net/pdf?id=qrwe7XHTmYb',
#  'https://openreview.net/pdf?id=TVjLza1t4hI',
#  'https://openreview.net/pdf?id=OmtmcPkkhT',
#  'https://openreview.net/pdf?id=7uVcpu-gMD',
#  'https://openreview.net/pdf?id=ZDnzZrTqU9N',
#  'https://openreview.net/pdf?id=6isfR3JCbi',
#  'https://openreview.net/pdf?id=Ig53hpHxS4',
#  'https://openreview.net/pdf?id=v9hAX77--cZ',
#  'https://openreview.net/pdf?id=hSjxQ3B7GWq',
#  'https://openreview.net/pdf?id=lf7st0bJIA5',
#  'https://openreview.net/pdf?id=bB2drc7DPuB',
#  'https://openreview.net/pdf?id=Nc3TJqbcl3',
#  'https://openreview.net/pdf?id=ONBPHFZ7zG4',
#  'https://openreview.net/pdf?id=F-mvpFpn_0q',
#  'https://openreview.net/pdf?id=ZcKPWuhG6wy',
#  'https://openreview.net/pdf?id=xoHdgbQJohv',
#  'https://openreview.net/pdf?id=C3qvk5IQIJY',
#  'https://openreview.net/pdf?id=giit4HdDNa',
#  'https://openreview.net/pdf?id=dx11_7vm5_r',
#  'https://openreview.net/pdf?id=-gfhS00XfKj',
#  'https://openreview.net/pdf?id=NsMLjcFaO8O',
#  'https://openreview.net/pdf?id=7EDgLu9reQD',
#  'https://openreview.net/pdf?id=0PtUPB9z6qK',
#  'https://openreview.net/pdf?id=qVyeW-grC2k',
#  'https://openreview.net/pdf?id=MyHwDabUHZm',
#  'https://openreview.net/pdf?id=eom0IUrF__F',
#  'https://openreview.net/pdf?id=gwFTuzxJW0',
#  'https://openreview.net/pdf?id=LiX3ECzDPHZ',
#  'https://openreview.net/pdf?id=J3OUycKwz-',
#  'https://openreview.net/pdf?id=vLaHRtHvfFp',
#  'https://openreview.net/pdf?id=V69LGwJ0lIN',
#  'https://openreview.net/pdf?id=yUxUNaj2Sl',
#  'https://openreview.net/pdf?id=JbuYF437WB6',
#  'https://openreview.net/pdf?id=Rcmk0xxIQV',
#  'https://openreview.net/pdf?id=v_1Soh8QUNc',
#  'https://openreview.net/pdf?id=7t1FcJUWhi3',
#  'https://openreview.net/pdf?id=OMNB1G5xzd4',
#  'https://openreview.net/pdf?id=xgGS6PmzNq6',
#  'https://openreview.net/pdf?id=BtZhsSGNRNi',
#  'https://openreview.net/pdf?id=YCXrx6rRCXO',
#  'https://openreview.net/pdf?id=HCSgyPUfeDj',
#  'https://openreview.net/pdf?id=v8b3e5jN66j',
#  'https://openreview.net/pdf?id=onxoVA9FxMw',
#  'https://openreview.net/pdf?id=qkLMTphG5-h',
#  'https://openreview.net/pdf?id=l-PrrQrK0QR',
#  'https://openreview.net/pdf?id=bM3L3I_853',
#  'https://openreview.net/pdf?id=uz5uw6gM0m',
#  'https://openreview.net/pdf?id=fGF8qAqpXXG',
#  'https://openreview.net/pdf?id=-ODN6SbiUU',
#  'https://openreview.net/pdf?id=D3PcGLdMx0',
#  'https://openreview.net/pdf?id=iQQK02mxVIT',
#  'https://openreview.net/pdf?id=Ptaz_zIFbX',
#  'https://openreview.net/pdf?id=MaZFq7bJif7',
#  'https://openreview.net/pdf?id=D_KeYoqCYC',
#  'https://openreview.net/pdf?id=xGZG2kS5bFk',
#  'https://openreview.net/pdf?id=Qk-Wq5AIjpq',
#  'https://openreview.net/pdf?id=mQPBmvyAuk',
#  'https://openreview.net/pdf?id=7dpmlkBuJFC',
#  'https://openreview.net/pdf?id=rRFIni1CYmy',
#  'https://openreview.net/pdf?id=djwS0m4Ft_A',
#  'https://openreview.net/pdf?id=oyZxhRI2RiE',
#  'https://openreview.net/pdf?id=iWLByfvUhN',
#  'https://openreview.net/pdf?id=3k20LAiHYL2',
#  'https://openreview.net/pdf?id=tH6_VWZjoq',
#  'https://openreview.net/pdf?id=8E1-f3VhX1o',
#  'https://openreview.net/pdf?id=cu7IUiOhujH',
#  'https://openreview.net/pdf?id=Cz3dbFm5u-',
#  'https://openreview.net/pdf?id=sRA5rLNpmQc',
#  'https://openreview.net/pdf?id=c9-WeM-ceB',
#  'https://openreview.net/pdf?id=c8P9NQVtmnO',
#  'https://openreview.net/pdf?id=g11CZSghXyY',
#  'https://openreview.net/pdf?id=fw-BHZ1KjxJ',
#  'https://openreview.net/pdf?id=u2YNJPcQlwq',
#  'https://openreview.net/pdf?id=z5Z023VBmDZ',
#  'https://openreview.net/pdf?id=DILxQP08O3B',
#  'https://openreview.net/pdf?id=7pgFL2Dkyyy',
#  'https://openreview.net/pdf?id=po-DLlBuAuz',
#  'https://openreview.net/pdf?id=AHOs7Sm5H7R',
#  'https://openreview.net/pdf?id=vYeQQ29Tbvx',
#  'https://openreview.net/pdf?id=IgIk8RRT-Z',
#  'https://openreview.net/pdf?id=ahAUv8TI2Mz',
#  'https://openreview.net/pdf?id=ac288vnG_7U',
#  'https://openreview.net/pdf?id=M88oFvqp_9',
#  'https://openreview.net/pdf?id=O9bnihsFfXU',
#  'https://openreview.net/pdf?id=-Lr-u0b42he',
#  'https://openreview.net/pdf?id=TSRTzJnuEBS',
#  'https://openreview.net/pdf?id=pHXfe1cOmA',
#  'https://openreview.net/pdf?id=TgSVWXw22FQ',
#  'https://openreview.net/pdf?id=kyaIeYj4zZ',
#  'https://openreview.net/pdf?id=VcB4QkSfyO',
#  'https://openreview.net/pdf?id=kEnBH98BGs5',
#  'https://openreview.net/pdf?id=mCLVeEpplNE',
#  'https://openreview.net/pdf?id=JHcqXGaqiGn',
#  'https://openreview.net/pdf?id=PbEHqvFtcS',
#  'https://openreview.net/pdf?id=9z_dNsC4B5t',
#  'https://openreview.net/pdf?id=cP5IcoAkfKa',
#  'https://openreview.net/pdf?id=ehJqJQk9cw',
#  'https://openreview.net/pdf?id=l0V53bErniB',
#  'https://openreview.net/pdf?id=m4UCf24r0Y',
#  'https://openreview.net/pdf?id=NX1He-aFO_F',
#  'https://openreview.net/pdf?id=AY8zfZm0tDd',
#  'https://openreview.net/pdf?id=_kxlwvhOodK',
#  'https://openreview.net/pdf?id=vujTf_I8Kmc',
#  'https://openreview.net/pdf?id=dyjPVUc2KB',
#  'https://openreview.net/pdf?id=IqtonxWI0V3',
#  'https://openreview.net/pdf?id=HIGSa_3kOx3',
#  'https://openreview.net/pdf?id=euDnVs0Ynts',
#  'https://openreview.net/pdf?id=dOcQK-f4byz',
#  'https://openreview.net/pdf?id=5l9zj5G7vDY',
#  'https://openreview.net/pdf?id=lgNx56yZh8a',
#  'https://openreview.net/pdf?id=tV6oBfuyLTQ',
#  'https://openreview.net/pdf?id=Ec85b0tUwbA',
#  'https://openreview.net/pdf?id=JFKR3WqwyXR',
#  'https://openreview.net/pdf?id=dx4b7lm8jMM',
#  'https://openreview.net/pdf?id=8cpHIfgY4Dj',
#  'https://openreview.net/pdf?id=8Sqhl-nF50',
#  'https://openreview.net/pdf?id=PH5PH9ZO_4',
#  'https://openreview.net/pdf?id=umIdUL8rMH',
#  'https://openreview.net/pdf?id=Jacdvfjicf7',
#  'https://openreview.net/pdf?id=9p2ekP904Rs',
#  'https://openreview.net/pdf?id=4IwieFS44l',
#  'https://openreview.net/pdf?id=F2v4aqEL6ze',
#  'https://openreview.net/pdf?id=U4XLJhqwNF1',
#  'https://openreview.net/pdf?id=SHvF5xaueVn',
#  'https://openreview.net/pdf?id=wxRwhSdORKG',
#  'https://openreview.net/pdf?id=ESG-DMKQKsD',
#  'https://openreview.net/pdf?id=ZW0yXJyNmoG',
#  'https://openreview.net/pdf?id=USCNapootw',
#  'https://openreview.net/pdf?id=t86MwoUCCNe',
#  'https://openreview.net/pdf?id=j9Rv7qdXjd',
#  'https://openreview.net/pdf?id=-_Zp7r2-cGK',
#  'https://openreview.net/pdf?id=qpsl2dR9twy',
#  'https://openreview.net/pdf?id=1FvkSpWosOl',
#  'https://openreview.net/pdf?id=nVZtXBI6LNn',
#  'https://openreview.net/pdf?id=GH7QRzUDdXG',
#  'https://openreview.net/pdf?id=9SS69KwomAM',
#  'https://openreview.net/pdf?id=JoCR4h9O3Ew',
#  'https://openreview.net/pdf?id=j1RMMKeP2gR',
#  'https://openreview.net/pdf?id=oFp8Mx_V5FL',
#  'https://openreview.net/pdf?id=vQzcqQWIS0q',
#  'https://openreview.net/pdf?id=RmcPm9m3tnk',
#  'https://openreview.net/pdf?id=d-XzF81Wg1',
#  'https://openreview.net/pdf?id=TYXs_y84xRj',
#  'https://openreview.net/pdf?id=CYO5T-YjWZV',
#  'https://openreview.net/pdf?id=pGIHq1m7PU',
#  'https://openreview.net/pdf?id=hsFN92eQEla']

# %%
pdfnamelist
# Out:
#  Reproducible Neural Architecture Search for Speech Recognition',
#  'Scaling the Convex Barrier with Active Sets',
#  'Local Convergence Analysis of Gradient Descent Ascent with Finite Timescale Separation',
#  'Activation-level uncertainty in deep neural networks',
#  'Efficient Continual Learning with Modular Networks and Task-Driven Priors',
#  'No Cost Likelihood Manipulation at Test Time for Making Better Mistakes in Deep Networks',
#  'Ringing ReLUs: Harmonic Distortion Analysis of Nonlinear Feedforward Networks',
#  'Distance-Based Regularisation of Deep Networks for Fine-Tuning',
#  'Genetic Soft Updates for Policy Evolution in Deep Reinforcement Learning',
#  'Towards Faster and Stabilized GAN Training for High-fidelity Few-shot Image Synthesis',
#  'IsarStep: a Benchmark for High-level Mathematical Reasoning',
#  'Multi-Prize Lottery Ticket Hypothesis: Finding Accurate Binary Neural Networks by Pruning A Randomly Weighted Network',
#  'Average-case Acceleration for Bilinear Games and Normal Matrices',
#  'ECONOMIC HYPERPARAMETER OPTIMIZATION WITH BLENDED SEARCH STRATEGY',
#  'BSQ: Exploring Bit-Level Sparsity for Mixed-Precision Neural Network Quantization',
#  'AutoLRS: Automatic Learning-Rate Schedule by Bayesian Optimization on the Fly',
#  'BERTology Meets Biology: Interpreting Attention in Protein Language Models',
#  'Learning Task-General Representations with Generative Neuro-Symbolic Modeling',
#  'Zero-shot Synthesis with Group-Supervised Learning',
#  'Selective Classification Can Magnify Disparities Across Groups',
#  'Better Fine-Tuning by Reducing Representational Collapse',
#  'Training independent subnetworks for robust prediction',
#  'Meta-Learning of Structured Task Distributions in Humans and Machines',
#  'BiPointNet: Binary Neural Network for Point Clouds',
#  'Benchmarks for Deep Off-Policy Evaluation',
#  'Planning from Pixels using Inverse Dynamics Models',
#  'Understanding the effects of data parallelism and sparsity on neural network training',
#  'NOVAS: Non-convex Optimization via Adaptive Stochastic Search for End-to-end Learning and Control',
#  'MoVie: Revisiting Modulated Convolutions for Visual Counting and Beyond',
#  'NeMo: Neural Mesh Models of Contrastive Features for Robust 3D Pose Estimation',
#  'On Graph Neural Networks versus Graph-Augmented MLPs',
#  'Dual-mode ASR: Unify and Improve Streaming ASR with Full-context Modeling',
#  'Deep Learning meets Projective Clustering',
#  'Reinforcement Learning with Random Delays',
#  'Isotropy in the Contextual Embedding Space: Clusters and Manifolds',
#  'Spatio-Temporal Graph Scattering Transform',
#  'Deployment-Efficient Reinforcement Learning via Model-Based Offline Optimization',
#  'gradSim: Differentiable simulation for system identification and visuomotor control',
#  'Evaluations and Methods for Explanation through Robustness Analysis',
#  'RNNLogic: Learning Logic Rules for Reasoning on Knowledge Graphs',
#  'Can a Fruit Fly Learn Word Embeddings?',
#  'Neural representation and generation for RNA secondary structures',
#  'WaNet - Imperceptible Warping-based Backdoor Attack',
#  'LowKey: Leveraging Adversarial Attacks to Protect Social Media Users from Facial Recognition',
#  "Learning from others' mistakes: Avoiding dataset biases without modeling them",
#  'Prototypical Contrastive Learning of Unsupervised Representations',
#  'Extreme Memorization via Scale of Initialization',
#  'Interactive Weak Supervision: Learning Useful Heuristics for Data Labeling',
#  'Adaptive Procedural Task Generation for Hard-Exploration Problems',
#  'Multi-timescale Representation Learning in LSTM Language Models',
#  'Deep Encoder, Shallow Decoder: Reevaluating Non-autoregressive Machine Translation',
#  'Learning Better Structured Representations Using Low-rank Adaptive Label Smoothing',
#  'Predicting Inductive Biases of Pre-Trained Models',
#  'Molecule Optimization by Explainable Evolution',
#  'Anchor & Transform: Learning Sparse Embeddings for Large Vocabularies',
#  'PSTNet: Point Spatio-Temporal Convolution on Point Cloud Sequences',
#  'Group Equivariant Conditional Neural Processes',
#  'When does preconditioning help or hurt generalization?',
#  'Learning Reasoning Paths over Semantic Graphs for Video-grounded Dialogues',
#  'Prototypical Representation Learning for Relation Extraction',
#  'Layer-adaptive Sparsity for the Magnitude-based Pruning',
#  'Refining Deep Generative Models via Discriminator Gradient Flow',
#  'Explaining the Efficacy of Counterfactually Augmented Data',
#  'Lipschitz Recurrent Neural Networks',
#  'Learning Hyperbolic Representations of Topological Features',
#  'Bidirectional Variational Inference for Non-Autoregressive Text-to-Speech',
#  'Risk-Averse Offline Reinforcement Learning',
#  'Group Equivariant Stand-Alone Self-Attention For Vision',
#  'A Better Alternative to Error Feedback for Communication-Efficient Distributed Learning',
#  'Neural Delay Differential Equations',
#  'Capturing Label Characteristics in VAEs',
#  'Graph Edit Networks',
#  'InfoBERT: Improving Robustness of Language Models from An Information Theoretic Perspective',
#  'DrNAS: Dirichlet Neural Architecture Search',
#  'Drop-Bottleneck: Learning Discrete Compressed Representation for Noise-Robust Exploration',
#  'Monte-Carlo Planning and Learning with Language Action Value Estimates',
#  'Robust early-learning: Hindering the memorization of noisy labels',
#  'Identifying Physical Law of Hamiltonian Systems via Meta-Learning',
#  'Reweighting Augmented Samples by Minimizing the Maximal Expected Loss',
#  'Understanding and Improving Encoder Layer Fusion in Sequence-to-Sequence Learning',
#  'Spatial Dependency Networks: Neural Layers for Improved Generative Image Modeling',
#  'Deep Repulsive Clustering of Ordered Data Based on Order-Identity Decomposition',
#  'Revisiting Locally Supervised Learning: an Alternative to End-to-end Training',
#  'Nonseparable Symplectic Neural Networks',
#  'Gradient Origin Networks',
#  'Learning to Sample with Local and Global Contexts in Experience Replay Buffer',
#  'Provable Rich Observation Reinforcement Learning with Combinatorial Latent States',
#  'Sharper Generalization Bounds for Learning with Gradient-dominated Objective Functions',
#  'Rapid Neural Architecture Search by Learning to Generate Graphs from Datasets',
#  'Relating by Contrasting: A Data-efficient Framework for Multimodal Generative Models',
#  'FedMix: Approximation of Mixup under Mean Augmented Federated Learning',
#  'Generalized Variational Continual Learning',
#  'Understanding and Improving Lexical Choice in Non-Autoregressive Translation',
#  'Bayesian Context Aggregation for Neural Processes',
#  'Variational Intrinsic Control Revisited',
#  'Implicit Gradient Regularization',
#  'Return-Based Contrastive Representation Learning for Reinforcement Learning',
#  'Scalable Bayesian Inverse Reinforcement Learning',
#  'Exemplary Natural Images Explain CNN Activations Better than State-of-the-Art Feature Visualization',
#  'LiftPool: Bidirectional ConvNet Pooling',
#  'Adversarial score matching and improved sampling for image generation',
#  'Transient Non-stationarity and Generalisation in Deep Reinforcement Learning',
#  'On the Origin of Implicit Regularization in Stochastic Gradient Descent',
#  'Analyzing the Expressive Power of Graph Neural Networks in a Spectral Perspective',
#  'Pruning Neural Networks at Initialization: Why Are We Missing the Mark?',
#  'SkipW: Resource Adaptable RNN with Strict Upper Computational Limit',
#  'Into the Wild with AudioScope: Unsupervised Audio-Visual Separation of On-Screen Sounds',
#  'Simple Augmentation Goes a Long Way: ADRL for DNN Quantization',
#  'Few-Shot Bayesian Optimization with Deep Kernel Surrogates',
#  'AdaSpeech: Adaptive Text to Speech for Custom Voice',
#  'HeteroFL: Computation and Communication Efficient Federated Learning for Heterogeneous Clients',
#  'DINO: A Conditional Energy-Based GAN for Domain Translation',
#  'Universal Weakly Supervised Segmentation by Pixel-to-Segment Contrastive Learning',
#  'PC2WF: 3D Wireframe Reconstruction from Raw Point Clouds',
#  'Multi-resolution modeling of a discrete stochastic process identifies causes of cancer',
#  'C-Learning: Horizon-Aware Cumulative Accessibility Estimation',
#  'Shapley Explanation Networks',
#  'The role of Disentanglement in Generalisation',
#  'Learning N:M Fine-grained Structured Sparse Neural Networks From Scratch',
#  'Unsupervised Meta-Learning through Latent-Space Interpolation in Generative Models',
#  'On Data-Augmentation and Consistency-Based Semi-Supervised Learning',
#  'Learning from Demonstration with Weakly Supervised Disentanglement',
#  'Neurally Augmented ALISTA',
#  'Shape or Texture: Understanding Discriminative Features in CNNs',
#  'Convex Potential Flows: Universal Probability Distributions with Optimal Transport and Convex Optimization',
#  'Wasserstein Embedding for Graph Learning',
#  'Meta-learning with negative learning rates',
#  'Representing Partial Programs with Blended Abstract Semantics',
#  'Fast convergence of stochastic subgradient method under interpolation',
#  'A Hypergradient Approach to Robust Regression without Correspondence',
#  'On the role of planning in model-based deep reinforcement learning',
#  'Trajectory Prediction using Equivariant Continuous Convolution',
#  'Grounding Language to Autonomously-Acquired Skills via Goal Generation',
#  'Chaos of Learning Beyond Zero-sum and Coordination via Game Decompositions',
#  'Isometric Transformation Invariant and Equivariant Graph Convolutional Networks',
#  'R-GAP: Recursive Gradient Attack on Privacy',
#  'Multi-Level Local SGD: Distributed SGD for Heterogeneous Hierarchical Networks',
#  'GShard: Scaling Giant Models with Conditional Computation and Automatic Sharding',
#  'Representation learning for improved interpretability and classification accuracy of clinical factors from EEG',
#  'Multiplicative Filter Networks',
#  'Are Neural Nets Modular? Inspecting Functional Modularity Through Differentiable Weight Masks',
#  'Modeling the Second Player in Distributionally Robust Optimization',
#  'Private Post-GAN Boosting',
#  'Flowtron: an Autoregressive Flow-based Generative Network for Text-to-Speech Synthesis',
#  'Learning Structural Edits via Incremental Tree Transformations',
#  'Sample-Efficient Automated Deep Reinforcement Learning',
#  'Unsupervised Discovery of 3D Physical Objects',
#  'Global optimality of softmax policy gradient with single hidden layer neural networks in the mean-field regime',
#  'Extracting Strong Policies for Robotics Tasks from Zero-Order Trajectory Optimizers',
#  'Temporally-Extended ε-Greedy Exploration',
#  'Rapid Task-Solving in Novel Environments',
#  'Tradeoffs in Data Augmentation: An Empirical Study',
#  'Multiscale Score Matching for Out-of-Distribution Detection',
#  'Understanding Over-parameterization in Generative Adversarial Networks',
#  'Go with the flow: Adaptive control for Neural ODEs',
#  'Linear Last-iterate Convergence in Constrained Saddle-point Optimization',
#  'Learning advanced mathematical computations from examples',
#  'WaveGrad: Estimating Gradients for Waveform Generation',
#  'SALD: Sign Agnostic Learning with Derivatives',
#  'Generalized Energy Based Models',
#  'Long Range Arena : A Benchmark for Efficient Transformers',
#  'Beyond Categorical Label Representations for Image Classification',
#  'CoCo: Controllable Counterfactuals for Evaluating Dialogue State Trackers',
#  'Stochastic Security: Adversarial Defense Using Long-Run Dynamics of Energy-Based Models',
#  'X2T: Training an X-to-Text Typing Interface with Online Learning from User Feedback',
#  'Mapping the Timescale Organization of Neural Language Models',
#  'PDE-Driven Spatiotemporal Disentanglement',
#  'OPAL: Offline Primitive Discovery for Accelerating Offline Reinforcement Learning',
#  'Does enhanced shape bias improve neural network robustness to common corruptions?',
#  'Directed Acyclic Graph Neural Networks',
#  'QPLEX: Duplex Dueling Multi-Agent Q-Learning',
#  'Learning Energy-Based Models by Diffusion Recovery Likelihood',
#  'Neural Networks for Learning Counterfactual G-Invariances from Single Environments',
#  'Model-Based Offline Planning',
#  'On Dyadic Fairness: Exploring and Mitigating Bias in Graph Connections',
#  'Coping with Label Shift via Distributionally Robust Optimisation',
#  'Faster Binary Embeddings for Preserving Euclidean Distances',
#  'Learning and Evaluating Representations for Deep One-Class Classification',
#  'Conditional Negative Sampling for Contrastive Learning of Visual Representations',
#  'On Position Embeddings in BERT',
#  'Repurposing Pretrained Models for Robust Out-of-domain Few-Shot Learning',
#  'Dataset Meta-Learning from Kernel Ridge-Regression',
#  'AdaFuse: Adaptive Temporal Fusion Network for Efficient Action Recognition',
#  'One Network Fits All? Modular versus Monolithic Task Formulations in Neural Networks',
#  'Vector-output ReLU Neural Network Problems are Copositive Programs: Convex Analysis of Two Layer Networks and Polynomial-time Algorithms',
#  'In Defense of Pseudo-Labeling: An Uncertainty-Aware Pseudo-label Selection Framework for Semi-Supervised Learning',
#  'MELR: Meta-Learning via Modeling Episode-Level Relationships for Few-Shot Learning',
#  'Why resampling outperforms reweighting for correcting sampling bias with stochastic gradients',
#  'Prediction and generalisation over directed actions by grid cells',
#  'Hopper: Multi-hop Transformer for Spatiotemporal Reasoning',
#  'Sparse encoding for more-interpretable feature-selecting representations in probabilistic matrix factorization',
#  'Dance Revolution: Long-Term Dance Generation with Music via Curriculum Learning',
#  'PAC Confidence Predictions for Deep Neural Network Classifiers',
#  'BREEDS: Benchmarks for Subpopulation Shift',
#  'Bypassing the Ambient Dimension: Private SGD with Gradient Subspace Identification',
#  'End-to-End Egospheric Spatial Memory',
#  'Evaluating the Disentanglement of Deep Generative Models through Manifold Topology',
#  'SCoRe: Pre-Training for Context Representation in Conversational Semantic Parsing',
#  'Decoupling Global and Local Representations via Invertible Generative Flows',
#  'Pre-training Text-to-Text Transformers for Concept-centric Common Sense',
#  'Local Search Algorithms for Rank-Constrained Convex Optimization',
#  'Combining Label Propagation and Simple Models out-performs Graph Neural Networks',
#  'Supervised Contrastive Learning for Pre-trained Language Model Fine-tuning',
#  'SAFENet: A Secure, Accurate and Fast Neural Network Inference',
#  'Provably robust classification of adversarial examples with detection',
#  'Saliency is a Possible Red Herring When Diagnosing Poor Generalization',
#  'Fourier Neural Operator for Parametric Partial Differential Equations',
#  'Combining Ensembles and Data Augmentation Can Harm Your Calibration',
#  'SOLAR: Sparse Orthogonal Learned and Random Embeddings',
#  'Efficient Empowerment Estimation for Unsupervised Stabilization',
#  'More or Less: When and How to Build Convolutional Neural Network Ensembles',
#  'VTNet: Visual Transformer Network for Object Goal Navigation',
#  'Class Normalization for (Continual)? Generalized Zero-Shot Learning',
#  'Batch Reinforcement Learning Through Continuation Method',
#  'Towards Resolving the Implicit Bias of Gradient Descent for Matrix Factorization: Greedy Low-Rank Learning',
#  'Training BatchNorm and Only BatchNorm: On the Expressive Power of Random Features in CNNs',
#  'CompOFA – Compound Once-For-All Networks for Faster Multi-Platform Deployment',
#  'Adaptive and Generative Zero-Shot Learning',
#  'Learning to Make Decisions via Submodular Regularization',
#  'Generating Furry Cars: Disentangling Object Shape and Appearance across Multiple Domains',
#  'Implicit Under-Parameterization Inhibits Data-Efficient Deep Reinforcement Learning',
#  'Disentangling 3D Prototypical Networks for Few-Shot Concept Learning',
#  'Anytime Sampling for Autoregressive Models via Ordered Autoencoding',
#  'HyperDynamics: Meta-Learning Object and Agent Dynamics with Hypernetworks',
#  'Improving Zero-Shot Voice Style Transfer via Disentangled Representation Learning',
#  'GraPPa: Grammar-Augmented Pre-Training for Table Semantic Parsing',
#  'Estimating Lipschitz constants of monotone deep equilibrium models',
#  'Estimating informativeness of samples with Smooth Unique Information',
#  'NBDT: Neural-Backed Decision Tree',
#  'Accurate Learning of Graph Representations with Graph Multiset Pooling',
#  'Byzantine-Resilient Non-Convex Stochastic Gradient Descent',
#  'MetaNorm: Learning to Normalize Few-Shot Batches Across Domains',
#  'Large Batch Simulation for Deep Reinforcement Learning',
#  'Personalized Federated Learning with First Order Model Optimization',
#  'Combining Physics and Machine Learning for Network Flow Estimation',
#  'Knowledge Distillation as Semiparametric Inference',
#  'Learning Value Functions in Deep Policy Gradients using Residual Variance',
#  'Randomized Ensembled Double Q-Learning: Learning Fast Without a Model',
#  'Decentralized Attribution of Generative Models',
#  'Attentional Constellation Nets for Few-Shot Learning',
#  'Adapting to Reward Progressivity via Spectral Reinforcement Learning',
#  'TropEx: An Algorithm for Extracting Linear Terms in Deep Neural Networks',
#  'Reset-Free Lifelong Learning with Skill-Space Planning',
#  'Robust Learning of Fixed-Structure Bayesian Networks in Nearly-Linear Time',
#  'Teaching Temporal Logics to Neural Networks',
#  'Spatially Structured Recurrent Modules',
#  'Bayesian Few-Shot Classification with One-vs-Each Pólya-Gamma Augmented Gaussian Processes',
#  'Parameter-Based Value Functions',
#  'Hyperbolic Neural Networks++',
#  'Neural Jump Ordinary Differential Equations: Consistent Continuous-Time Prediction and Filtering',
#  'Seq2Tens: An Efficient Representation of Sequences by Low-Rank Tensor Projections',
#  'Efficient Fully-Offline Meta-Reinforcement Learning via Distance Metric Learning and Behavior Regularization',
#  'On the Curse of Memory in Recurrent Neural Networks: Approximation and Optimization Analysis',
#  'Generating Adversarial Computer Programs using Optimized Obfuscations',
#  'BOIL: Towards Representation Change for Few-shot Learning',
#  'Interpreting and Boosting Dropout from a Game-Theoretic View',
#  'Representation Learning via Invariant Causal Mechanisms',
#  'Fooling a Complete Neural Network Verifier',
#  'CPR: Classifier-Projection Regularization for Continual Learning',
#  'CO2: Consistent Contrast for Unsupervised Visual Representation Learning',
#  'GAN2GAN: Generative Noise Learning for Blind Denoising with Single Noisy Images',
#  'Learning Subgoal Representations with Slow Dynamics',
#  'Bowtie Networks: Generative Modeling for Joint Few-Shot Recognition and Novel-View Synthesis',
#  'Taming GANs with Lookahead-Minmax',
#  'Certify or Predict: Boosting Certified Robustness with Compositional Architectures',
#  'New Bounds For Distributed Mean Estimation and Variance Reduction',
#  'Interpretable Neural Architecture Search via Bayesian Optimisation with Weisfeiler-Lehman Kernels',
#  'A Discriminative Gaussian Mixture Model with Sparsity',
#  'Communication in Multi-Agent Reinforcement Learning: Intention Sharing',
#  'Is Attention Better Than Matrix Decomposition?',
#  'Fast and Complete: Enabling Complete Neural Network Verification with Rapid and Massively Parallel Incomplete Verifiers',
#  'A Geometric Analysis of Deep Generative Image Models and Its Applications',
#  'Solving Compositional Reinforcement Learning Problems via Task Reduction',
#  'ARMOURED: Adversarially Robust MOdels using Unlabeled data by REgularizing Diversity',
#  'Acting in Delayed Environments with Non-Stationary Markov Policies',
#  'Overfitting for Fun and Profit: Instance-Adaptive Data Compression',
#  'Learnable Embedding sizes for Recommender Systems',
#  'Generative Scene Graph Networks',
#  'Deconstructing the Regularization of BatchNorm',
#  'PolarNet: Learning to Optimize Polar Keypoints for Keypoint Based Object Detection',
#  'Simple Spectral Graph Convolution',
#  'Explainable Subgraph Reasoning for Forecasting on Temporal Knowledge Graphs',
#  'EVALUATION OF NEURAL ARCHITECTURES TRAINED WITH SQUARE LOSS VS CROSS-ENTROPY IN CLASSIFICATION TASKS']

# %%
for i, url in enumerate(pdfurllist):
    if url != None :      
        print(i, '\t', pdfnamelist[i], '\t', pdfurllist[i])
        data = urllib.request.urlopen(pdfurllist[i]).read()
        # pdfname = pdfnamelist[i].replace('?', '').replace('"', '').replace('\\', '').replace('/', '').replace('*', ''). \
        #                                             replace('>', '').replace('<', '').replace('|', '').replace(':', '.')
        pdfname = slugify(pdfnamelist[i])
        with open(root+'/'+pdfname+".pdf", 'wb')  as f:
            f.write(data)  
        _ = time.sleep(random.uniform(4,5))
# Out:
# 76 	 Beyond Fully-Connected Layers with Quaternions: Parameterization of Hypercomplex Multiplications with
# 1/n
# Parameters 	 https://openreview.net/pdf?id=rcQdycl0zyk
# 77 	 Distributional Sliced-Wasserstein and Applications to Generative Modeling 	 https://openreview.net/pdf?id=QYjO70ACDK
# 78 	 Async-RED: A Provably Convergent Asynchronous Block Parallel Stochastic Method using Deep Denoising Priors 	 https://openreview.net/pdf?id=9EsrXMzlFQY
# 79 	 DeepAveragers: Offline Reinforcement Learning By Solving Derived Non-Parametric MDPs 	 https://openreview.net/pdf?id=eMP1j9efXtX
# 80 	 Learning from Protein Structure with Geometric Vector Perceptrons 	 https://openreview.net/pdf?id=1YLJDvSx6J4
# 81 	 Behavioral Cloning from Noisy Demonstrations 	 https://openreview.net/pdf?id=zrT3HcsWSAt
# 82 	 Undistillable: Making A Nasty Teacher That CANNOT teach students 	 https://openreview.net/pdf?id=0zvfm-nZqQs
# 83 	 Multivariate Probabilistic Time Series Forecasting via Conditioned Normalizing Flows 	 https://openreview.net/pdf?id=WiGQBFuVRv
# 84 	 Image Augmentation Is All You Need: Regularizing Deep Reinforcement Learning from Pixels 	 https://openreview.net/pdf?id=GY6-6sTvGaf
# 85 	 HW-NAS-Bench: Hardware-Aware Neural Architecture Search Benchmark 	 https://openreview.net/pdf?id=_0kaDkv3dVf
# 86 	 Practical Real Time Recurrent Learning with a Sparse Approximation 	 https://openreview.net/pdf?id=q3KSThy2GwB
# 87 	 Random Feature Attention 	 https://openreview.net/pdf?id=QtTKTdVrFBB
# 88 	 A Gradient Flow Framework For Analyzing Network Pruning 	 https://openreview.net/pdf?id=rumv7QmLUue
# 89 	 Recurrent Independent Mechanisms 	 https://openreview.net/pdf?id=mLcmdlEUxy-
# 90 	 The Intrinsic Dimension of Images and Its Impact on Learning 	 https://openreview.net/pdf?id=XJk19XzGq2J
# 91 	 Uncertainty Sets for Image Classifiers using Conformal Prediction 	 https://openreview.net/pdf?id=eNdiU_DbM9
# 92 	 Sequential Density Ratio Estimation for Simultaneous Optimization of Speed and Accuracy 	 https://openreview.net/pdf?id=Rhsu5qD36cL
# 93 	 Disentangled Recurrent Wasserstein Autoencoder 	 https://openreview.net/pdf?id=O7ms4LFdsX
# 94 	 Generalization bounds via distillation 	 https://openreview.net/pdf?id=EGdFhBzmAwB
# 95 	 Neural Approximate Sufficient Statistics for Implicit Models 	 https://openreview.net/pdf?id=SRDuJssQud
# 96 	 A Panda? No, It's a Sloth: Slowdown Attacks on Adaptive Multi-Exit Neural Network Inference 	 https://openreview.net/pdf?id=9xC2tWEwBD
# 97 	 Orthogonalizing Convolutional Layers with the Cayley Transform 	 https://openreview.net/pdf?id=Pbj8H_jEHYv
# 98 	 LambdaNetworks: Modeling long-range Interactions without Attention 	 https://openreview.net/pdf?id=xTJEN-ggl1b
# 99 	 Mind the Pad -- CNNs Can Develop Blind Spots 	 https://openreview.net/pdf?id=m1CD7tPubNy
# 100 	 Meta-GMVAE: Mixture of Gaussian VAE for Unsupervised Meta-Learning 	 https://openreview.net/pdf?id=wS0UFjsNYjn
# 101 	 Fast Geometric Projections for Local Robustness Certification 	 https://openreview.net/pdf?id=zWy1uxjDdZJ
# 102 	 Fidelity-based Deep Adiabatic Scheduling 	 https://openreview.net/pdf?id=NECTfffOvn1
# 103 	 On Self-Supervised Image Representations for GAN Evaluation 	 https://openreview.net/pdf?id=NeRdBeTionN
# 104 	 Retrieval-Augmented Generation for Code Summarization via Hybrid GNN 	 https://openreview.net/pdf?id=zv-typ1gPxA
# 105 	 Self-supervised Visual Reinforcement Learning with Object-centric Representations 	 https://openreview.net/pdf?id=xppLmXCbOw1
# 106 	 Identifying nonlinear dynamical systems with multiple time scales and long-range dependencies 	 https://openreview.net/pdf?id=_XYzwxPIQu6
# 107 	 Neural Topic Model via Optimal Transport 	 https://openreview.net/pdf?id=Oos98K9Lv-k
# 108 	 Memory Optimization for Deep Networks 	 https://openreview.net/pdf?id=bnY0jm4l59
# 109 	 Stabilized Medical Image Attacks 	 https://openreview.net/pdf?id=QfTXQiGYudJ
# 110 	 Quantifying Differences in Reward Functions 	 https://openreview.net/pdf?id=LwEQnp6CYev
# 111 	 MARS: Markov Molecular Sampling for Multi-objective Drug Discovery 	 https://openreview.net/pdf?id=kHSu4ebxFXY
# 112 	 Gauge Equivariant Mesh CNNs: Anisotropic convolutions on geometric graphs 	 https://openreview.net/pdf?id=Jnspzp-oIZE
# 113 	 RMSprop converges with proper hyper-parameter 	 https://openreview.net/pdf?id=3UDSdyIcBDA

# %%
# pdfname = shorturl[shorturl.rindex("/")+1:]
data = urllib.request.urlopen(pdfurllist[1]).read()
with open(pdfnamelist[1]+".pdf", 'wb')  as f:
    f.write(data)  
time.sleep(random.uniform(4,5))
# Out:
# 2272358

# %%
'Beyond Fully-Connected Layers with Quaternions. Parameterization of Hypercomplex Multiplications with\n1n\nParameters'[:255]#.replace('\\', '')
# Out:
# 'Beyond Fully-Connected Layers with Quaternions. Parameterization of Hypercomplex Multiplications with\n1n\nParameters'

# %%
slugify('Beyond Fully-Connected Layers with Quaternions. Parameterization of Hypercomplex Multiplications with\n1n\nParameters')
# Out:
# 'beyond-fully-connected-layers-with-quaternions-parameterization-of-hypercomplex-multiplications-with-1n-parameters'

# %%
"".join( x for x in 'Beyond Fully-Connected Layers with Quaternions. Parameterization of Hypercomplex Multiplications with\n1n\nParameters' if (x.isalnum() or x in "._- "))
# Out:
# 'Beyond Fully-Connected Layers with Quaternions. Parameterization of Hypercomplex Multiplications with1nParameters'

# %%
# driver = webdriver.Chrome('C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe')  

# driver.get("https://openreview.net/group?id=ICLR.cc/2021/Conference")
# # elem = driver.find_element_by_id("ext-gen67")
# # #elem.send_keys(Keys.RETURN)
# # print(elem)
# # elem.click()

# i= 0
# elementllist =  driver.find_elements_by_name("FullTextPDF")
# pdfurllist =  []

# for element in elementllist: 
#     pdfurllist.append(element.get_attribute('href'))
#     i = i+1

# import os
# os.mkdir("chi2012")

# i = 0
# for url in pdfurllist:
#     if url != None :      
#         i = i+1
#         print i
#         driver.get(url)
#         pdf = driver.current_url
#         shorturl = pdf[0:pdf.index(".pdf")]
#         pdfname = shorturl[shorturl.rindex("/")+1:]
#         print pdfname
#         data = urllib.urlopen(pdf).read()
#         f = open("pdf\\"+pdfname+".pdf", 'wb')  
#         f.write(data)  
#         f.close()  

# driver.close()
